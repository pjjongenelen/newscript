# %%
from helpers import *
import general
import pandas as pd

# %% [markdown]
# # MUC-4

# %%
df = load_muc()
df
# Out:
#               muc_id         location       date  \
# 0      DEV-MUC3-0001     SAN SALVADOR   3 JAN 90
# 1      DEV-MUC3-0002     SAN SALVADOR   4 JAN 90
# 2      DEV-MUC3-0003         SANTIAGO   5 JAN 90
# 3      DEV-MUC3-0004      CLANDESTINE   8 JAN 90
# 4      DEV-MUC3-0005      CLANDESTINE   8 JAN 90
# ...              ...              ...        ...
# 1695  TST4-MUC4-0096  RIO DE JANEIRO   22 DEC 88
# 1696  TST4-MUC4-0097           BOGOTA  25 DEC 88
# 1697  TST4-MUC4-0098     SAN SALVADOR  22 DEC 88
# 1698  TST4-MUC4-0099         SANTIAGO  21 DEC 88
# 1699  TST4-MUC4-0100             LIMA  27 DEC 88
#
#                                                    text
# 0     THE ARCE BATTALION COMMAND HAS REPORTED THAT A...
# 1     ACCORDING TO STATEMENTS MADE BY A SALVADORAN O...
# 2     THE GOVERNMENT JUNTA YESTERDAY APPROVED A DRAF...
# 3     GOODBYE GENERAL RAFAEL BUSTILLO, FALSE HOPE FO...
# 4     A WAR BULLETIN INDICATES THAT ON 6 JANUARY AT ...
# ...

# %% [markdown]
# # Topic modeling on MUC

# %%
docs = topic_modeling(df['text'], ntopics=10, iterations=400)
# Out:
# Topic: 1 Word: 0.005*"nicaraguan" + 0.004*"presid" + 0.004*"salvadoran" + 0.003*"nicaragua" + 0.003*"ortega" + 0.003*"contra" + 0.003*"cristiani" + 0.003*"peopl" + 0.003*"bomb" + 0.002*"parti"
# Topic: 2 Word: 0.004*"fmln" + 0.003*"drug" + 0.003*"guerrilla" + 0.003*"dialogu" + 0.003*"salvadoran" + 0.003*"rebel" + 0.003*"militari" + 0.003*"salvador" + 0.003*"attack" + 0.003*"forc"
# Topic: 3 Word: 0.004*"drug" + 0.004*"nicaraguan" + 0.003*"presid" + 0.003*"honduran" + 0.003*"contra" + 0.003*"attack" + 0.003*"guerrilla" + 0.002*"medellin" + 0.002*"extradit" + 0.002*"unit"
# Topic: 4 Word: 0.005*"fmln" + 0.004*"salvadoran" + 0.003*"attack" + 0.003*"polic" + 0.003*"peopl" + 0.003*"peac" + 0.003*"arm" + 0.003*"terrorist" + 0.003*"cristiani" + 0.003*"guerrilla"
# Topic: 5 Word: 0.004*"salvador" + 0.004*"attack" + 0.003*"arrest" + 0.003*"univers" + 0.003*"fmln" + 0.003*"neighborhood" + 0.003*"student" + 0.003*"salvadoran" + 0.003*"explos" + 0.003*"forc"
# ...

# %%
for x in range(7,16):
    docs = topic_modeling(df['text'], ntopics=x)
    print(f'MUC TOPIC MODELING WITH {x} TOPICS')
    print('----------------------------------------------------')
    print('----------------------------------------------------')
    print('----------------------------------------------------')
    print('----------------------------------------------------')
    print('----------------------------------------------------')
    print(docs)
# Out:
# Topic: 0 Word: 0.003*"attack" + 0.003*"salvadoran" + 0.003*"cristiani" + 0.003*"arm" + 0.002*"drug" + 0.002*"terrorist" + 0.002*"forc" + 0.002*"fmln" + 0.002*"group" + 0.002*"polic"
# Topic: 1 Word: 0.005*"honduran" + 0.005*"drug" + 0.003*"terrorist" + 0.003*"polic" + 0.003*"kill" + 0.003*"salvadoran" + 0.003*"minist" + 0.003*"oper" + 0.003*"colombian" + 0.003*"clash"
# Topic: 2 Word: 0.003*"bomb" + 0.003*"kill" + 0.003*"depart" + 0.003*"injur" + 0.003*"attack" + 0.003*"judg" + 0.003*"armi" + 0.003*"troop" + 0.003*"fmln" + 0.003*"militari"
# Topic: 3 Word: 0.006*"drug" + 0.004*"polic" + 0.004*"bogota" + 0.004*"medellin" + 0.003*"attack" + 0.003*"colombian" + 0.003*"colombia" + 0.003*"traffick" + 0.003*"explos" + 0.003*"bomb"
# Topic: 4 Word: 0.005*"salvador" + 0.004*"attack" + 0.004*"fmln" + 0.004*"guerrilla" + 0.004*"salvadoran" + 0.003*"casualti" + 0.003*"soldier" + 0.003*"forc" + 0.003*"rebel" + 0.003*"militari"
# ...

# %% [markdown]
# # Topic modeling on the GNM data

# %%
data_path = 'C:/Users/s161158/OneDrive - TU Eindhoven/Silva_Ducis/Master_Thesis/drugs data'
df = general.load_drugs_data(data_path, cols = ['article_contentRaw'], n = 13000)
text = [x for d in df for x in d]

print(f'Original length: {len(text)}')
to_remove = []
for i in range(len(text)):
    if not isinstance(text[i], str):
        to_remove.append(i)

to_remove.sort(reverse=True)
for rem in to_remove:
    del text[rem]
print(f'Length after filtering for non-string values: {len(text)}')
# Out:
# Loaded 13000 articles.
# Original length: 13000
# Length after filtering for non-string values: 12030

# %%
docs = topic_modeling(text, ntopics=10, iterations=400)
# Out:
# Topic: 1 Word: 0.002*"canada" + 0.002*"health" + 0.002*"patient" + 0.002*"prescript" + 0.002*"govern" + 0.002*"state" + 0.002*"price" + 0.002*"medicin" + 0.002*"import" + 0.002*"peopl"
# Topic: 2 Word: 0.003*"prescript" + 0.002*"philippin" + 0.002*"peopl" + 0.002*"opioid" + 0.002*"medic" + 0.002*"depress" + 0.002*"dutert" + 0.002*"prescrib" + 0.002*"anti" + 0.002*"report"
# Topic: 3 Word: 0.002*"court" + 0.002*"patient" + 0.002*"state" + 0.002*"execut" + 0.002*"smuggl" + 0.002*"arrest" + 0.002*"sentenc" + 0.002*"test" + 0.002*"prison" + 0.002*"singh"
# Topic: 4 Word: 0.005*"indict" + 0.004*"rekord" + 0.004*"count" + 0.004*"possess" + 0.003*"aggrav" + 0.002*"patient" + 0.002*"counti" + 0.002*"dagga" + 0.002*"arrest" + 0.002*"illeg"
# Topic: 5 Word: 0.006*"degre" + 0.004*"feloni" + 0.004*"island" + 0.003*"possess" + 0.003*"fifth" + 0.003*"indict" + 0.002*"yacht" + 0.002*"sell" + 0.002*"count" + 0.002*"school"
# ...

# %%
for x in range(7,16):
    docs = topic_modeling(text, ntopics=x)
    print(f'GNM TOPIC MODELING WITH {x} TOPICS')
    print('----------------------------------------------------')
    print('----------------------------------------------------')
    print('----------------------------------------------------')
    print('----------------------------------------------------')
    print('----------------------------------------------------')
    print(docs)
# Out:
# Topic: 0 Word: 0.003*"market" + 0.003*"region" + 0.002*"execut" + 0.002*"asean" + 0.002*"state" + 0.002*"govern" + 0.002*"illeg" + 0.002*"countri" + 0.002*"arrest" + 0.002*"kill"
# Topic: 1 Word: 0.004*"possess" + 0.003*"arrest" + 0.003*"prison" + 0.003*"court" + 0.003*"charg" + 0.002*"sentenc" + 0.002*"suspect" + 0.002*"class" + 0.002*"suppli" + 0.002*"search"
# Topic: 2 Word: 0.003*"island" + 0.002*"iran" + 0.002*"narcot" + 0.002*"arrest" + 0.002*"indict" + 0.002*"possess" + 0.002*"count" + 0.002*"yacht" + 0.002*"pill" + 0.002*"sell"
# Topic: 3 Word: 0.004*"patient" + 0.003*"canada" + 0.003*"health" + 0.003*"medicin" + 0.003*"price" + 0.003*"prescript" + 0.003*"medic" + 0.003*"covid" + 0.003*"compani" + 0.003*"state"
# Topic: 4 Word: 0.002*"peopl" + 0.002*"opioid" + 0.002*"addict" + 0.002*"possess" + 0.002*"cannabi" + 0.002*"govern" + 0.002*"health" + 0.002*"suppli" + 0.002*"prescript" + 0.002*"seiz"
# ...

# %% [markdown]
# # Clustering the GNM data

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

def k_means(docs, true_k = 10, verbose= False):
    # very basic knn algorithm for text, from:
    # https://towardsdatascience.com/applying-machine-learning-to-classify-an-unsupervised-text-document-e7bb6265f52

    vectorizer = TfidfVectorizer(stop_words='english')
    X = vectorizer.fit_transform(docs)

    model = KMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)
    model.fit(X)

    order_centroids = model.cluster_centers_.argsort()[:, ::-1]
    terms = vectorizer.get_feature_names_out()

    if verbose:
        for i in range(true_k):
            print(f"Cluster {i}:-------------------------------")
            for ind in order_centroids[i, :10]:  # returns the 10 top words of this cluster
                print(f'{terms[ind]}')

    return model

# %%
kmeans_model = k_means(text, true_k = 2, verbose = True)
# Out:
# Cluster 0:
# indicted
# count
# possession
# aggravated
# direct
# hamilton
# ave
# middletown
# st
# counts
# Cluster 1:
# drugs
# said
# drug
# police
# people
# arrested
# health
# year
# government
# court

# %%
kmeans_model = k_means(text, true_k = 3, verbose = True)
# Out:
# Cluster 0:
# drugs
# drug
# said
# health
# people
# government
# market
# patients
# use
# president
# Cluster 1:
# indicted
# count
# possession
# aggravated
# direct
# hamilton
# ave
# middletown
# st
# counts
# Cluster 2:
# police
# drugs
# said
# arrested
# drug
# court
# possession
# seized
# officers
# cocaine

# %%
kmeans_model = k_means(text, true_k = 4, verbose = True)
# Out:
# Cluster 0:
# drugs
# drug
# said
# health
# people
# government
# patients
# market
# use
# president
# Cluster 1:
# indicted
# count
# possession
# aggravated
# direct
# hamilton
# ave
# middletown
# st
# counts
# Cluster 2:
# police
# drugs
# said
# arrested
# drug
# court
# possession
# seized
# officers
# cocaine
# Cluster 3:
# asean
# unodc
# southeast
# asia
# region
# methamphetamine
# asod
# synthetic
# countries
# drugs

# %%
kmeans_model = k_means(text, true_k = 5, verbose = True)
# Out:
# Cluster 0:
# depressants
# term
# opioids
# review
# phe
# anxiety
# anti
# benzodiazepines
# people
# long
# Cluster 1:
# indicted
# count
# possession
# aggravated
# direct
# hamilton
# ave
# middletown
# st
# counts
# Cluster 2:
# duterte
# president
# war
# philippines
# robredo
# said
# drug
# drugs
# illegal
# police
# Cluster 3:
# drugs
# drug
# health
# said
# patients
# market
# people
# government
# use
# canada
# Cluster 4:
# drugs
# police
# said
# drug
# arrested
# court
# possession
# seized
# cocaine
# year

# %%
kmeans_model = k_means(text, true_k = 6, verbose = True)
# Out:
# Cluster 0:
# indicted
# count
# possession
# aggravated
# direct
# hamilton
# ave
# middletown
# st
# counts
# Cluster 1:
# police
# drugs
# said
# arrested
# possession
# drug
# court
# seized
# man
# cocaine
# Cluster 2:
# drugs
# market
# drug
# canada
# pharmaceutical
# cancer
# health
# companies
# prices
# medicines
# Cluster 3:
# drugs
# said
# drug
# people
# health
# use
# government
# state
# new
# country
# Cluster 4:
# covid
# 19
# patients
# hydroxychloroquine
# coronavirus
# drugs
# businesses
# local
# beijing
# adverts
# Cluster 5:
# duterte
# drugs
# drug
# said
# asean
# illegal
# president
# robredo
# war
# philippines

# %%
kmeans_model = k_means(text, true_k = 7, verbose = True)
# Out:
# Cluster 0:
# drugs
# said
# health
# patients
# drug
# medicines
# covid
# state
# medical
# people
# Cluster 1:
# indicted
# count
# possession
# aggravated
# direct
# hamilton
# ave
# middletown
# st
# counts
# Cluster 2:
# police
# drugs
# said
# arrested
# drug
# court
# possession
# seized
# cocaine
# officers
# Cluster 3:
# anf
# kg
# recovered
# hashish
# sanaullah
# lahore
# pml
# operation
# resident
# station
# Cluster 4:
# canada
# drugs
# prices
# drug
# prescription
# health
# companies
# cost
# canadian
# costs
# Cluster 5:
# drugs
# drug
# said
# duterte
# war
# president
# illegal
# government
# police
# people
# Cluster 6:
# market
# global
# drugs
# 24weeks
# 99per
# cannabis
# research
# com
# growth
# report

# %%
kmeans_model = k_means(text, true_k = 8, verbose = True)
# Out:
# Cluster 0:
# covid
# 19
# hydroxychloroquine
# patients
# coronavirus
# chloroquine
# virus
# trials
# vaccine
# drugs
# Cluster 1:
# indicted
# count
# possession
# aggravated
# direct
# hamilton
# ave
# middletown
# st
# counts
# Cluster 2:
# duterte
# president
# war
# drug
# drugs
# said
# philippines
# robredo
# illegal
# police
# Cluster 3:
# drugs
# said
# police
# court
# drug
# possession
# cocaine
# arrested
# county
# degree
# Cluster 4:
# canada
# drugs
# prices
# drug
# prescription
# companies
# health
# pharmaceutical
# canadian
# costs
# Cluster 5:
# drugs
# said
# drug
# health
# people
# market
# government
# use
# patients
# state
# Cluster 6:
# asean
# unodc
# region
# asod
# southeast
# countries
# methamphetamine
# asia
# aifocom
# drugs
# Cluster 7:
# police
# arrested
# drugs
# said
# seized
# recovered
# drug
# operation
# officers
# kg

# %%
kmeans_model = k_means(text, true_k = 9, verbose = True)
# Out:
# Cluster 0:
# local
# businesses
# adverts
# subscriber
# predominantly
# ads
# hd
# audience
# challenging
# promoting
# Cluster 1:
# drugs
# drug
# said
# health
# people
# patients
# government
# use
# state
# new
# Cluster 2:
# indicted
# count
# possession
# aggravated
# direct
# hamilton
# ave
# middletown
# st
# counts
# Cluster 3:
# police
# drugs
# said
# arrested
# seized
# drug
# officers
# man
# recovered
# operation
# Cluster 4:
# market
# cancer
# drugs
# research
# global
# china
# pharmaceutical
# navalny
# generic
# growth
# Cluster 5:
# illegal
# pdea
# drug
# robredo
# said
# drugs
# anti
# pnp
# campaign
# duterte
# Cluster 6:
# asean
# unodc
# southeast
# asia
# region
# asod
# methamphetamine
# synthetic
# countries
# drugs
# Cluster 7:
# drugs
# court
# possession
# degree
# said
# guilty
# cocaine
# drug
# county
# police
# Cluster 8:
# duterte
# president
# philippines
# war
# police
# said
# killed
# manila
# rodrigo
# drugs

# %%
kmeans_model = k_means(text, true_k = 10, verbose = True)
# Out:
# Cluster 0:-------------------------------
# drugs
# patients
# market
# health
# covid
# said
# 19
# cancer
# medical
# people
# Cluster 1:-------------------------------
# drugs
# said
# drug
# court
# police
# cocaine
# arrested
# years
# guilty
# mr
# Cluster 2:-------------------------------
# duterte
# president
# robredo
# war
# philippines
# said
# drug
# police
# drugs
# illegal
# Cluster 3:-------------------------------
# unodc
# asean
# southeast
# asia
# region
# methamphetamine
# asod
# synthetic
# countries
# drugs
# Cluster 4:-------------------------------
# drugs
# medicines
# pharmaceutical
# said
# india
# china
# health
# products
# companies
# fake
# Cluster 5:-------------------------------
# indicted
# count
# possession
# aggravated
# direct
# hamilton
# ave
# middletown
# st
# counts
# Cluster 6:-------------------------------
# police
# arrested
# drugs
# seized
# said
# possession
# man
# officers
# recovered
# drug
# ...

# %%
kmeans_model = k_means(text, true_k = 11, verbose = True)
# Out:
# Cluster 0:-------------------------------
# drugs
# supply
# police
# class
# gang
# cocaine
# said
# crime
# seized
# organised
# Cluster 1:-------------------------------
# covid
# 19
# patients
# coronavirus
# hydroxychloroquine
# vaccine
# drugs
# said
# virus
# health
# Cluster 2:-------------------------------
# market
# drugs
# global
# research
# growth
# report
# forecast
# com
# www
# cancer
# Cluster 3:-------------------------------
# local
# businesses
# adverts
# mondaq
# subscriber
# predominantly
# ads
# hd
# audience
# articles
# Cluster 4:-------------------------------
# police
# drugs
# arrested
# said
# possession
# drug
# seized
# man
# court
# degree
# Cluster 5:-------------------------------
# duterte
# president
# robredo
# war
# philippines
# said
# illegal
# drug
# drugs
# police
# Cluster 6:-------------------------------
# indicted
# count
# possession
# aggravated
# direct
# hamilton
# ave
# middletown
# st
# counts
# ...

# %%
kmeans_model = k_means(text, true_k = 12, verbose = True)
# Out:
# Cluster 0:-------------------------------
# australia
# yacht
# australian
# islands
# island
# cook
# police
# reef
# aground
# man
# Cluster 1:-------------------------------
# drugs
# patients
# health
# market
# said
# medicines
# drug
# covid
# cancer
# people
# Cluster 2:-------------------------------
# degree
# felony
# fifth
# felonies
# indicted
# possession
# meigs
# ohio
# fourth
# investigated
# Cluster 3:-------------------------------
# canada
# drugs
# prices
# drug
# prescription
# canadian
# health
# companies
# pharmaceutical
# plan
# Cluster 4:-------------------------------
# asean
# unodc
# southeast
# asia
# region
# asod
# methamphetamine
# synthetic
# countries
# drugs
# Cluster 5:-------------------------------
# india
# devices
# medical
# gulfnews
# drugs
# reader
# export
# fdcs
# essential
# dear
# Cluster 6:-------------------------------
# police
# drugs
# said
# arrested
# possession
# court
# officers
# man
# drug
# old
# ...

# %%
kmeans_model = k_means(text, true_k = 13, verbose = True)
# Out:
# Cluster 0:-------------------------------
# asean
# unodc
# southeast
# asia
# region
# asod
# methamphetamine
# synthetic
# countries
# drugs
# Cluster 1:-------------------------------
# market
# drugs
# india
# medicines
# pharmaceutical
# cancer
# global
# china
# companies
# research
# Cluster 2:-------------------------------
# police
# possession
# charged
# drugs
# arrested
# man
# county
# old
# officers
# court
# Cluster 3:-------------------------------
# local
# businesses
# adverts
# peace
# kabul
# subscriber
# predominantly
# ads
# president
# prison
# Cluster 4:-------------------------------
# degree
# felony
# fifth
# felonies
# indicted
# possession
# meigs
# ohio
# fourth
# investigated
# Cluster 5:-------------------------------
# drugs
# cocaine
# class
# gang
# supply
# police
# operation
# crime
# said
# organised
# Cluster 6:-------------------------------
# drugs
# canada
# health
# drug
# prescription
# prices
# said
# patients
# state
# states
# ...

# %%
kmeans_model = k_means(text, true_k = 14, verbose = True)
# Out:
# Cluster 0:-------------------------------
# albania
# rumormongers
# italy
# maguindanao
# albanian
# said
# cannabis
# sobejana
# longford
# seized
# Cluster 1:-------------------------------
# drugs
# drug
# canada
# pharmaceutical
# health
# prices
# companies
# medicines
# cancer
# said
# Cluster 2:-------------------------------
# covid
# patients
# 19
# hydroxychloroquine
# coronavirus
# said
# drugs
# vaccine
# virus
# trials
# Cluster 3:-------------------------------
# mr
# court
# drugs
# said
# pellets
# police
# ms
# told
# heard
# trial
# Cluster 4:-------------------------------
# police
# possession
# county
# drugs
# charged
# court
# said
# officers
# drug
# arrested
# Cluster 5:-------------------------------
# iran
# paraguay
# hezbollah
# drugs
# drug
# iranian
# narcotics
# war
# international
# smuggling
# Cluster 6:-------------------------------
# indicted
# count
# possession
# aggravated
# direct
# hamilton
# ave
# middletown
# st
# counts
# ...

# %%
kmeans_model = k_means(text, true_k = 15, verbose = True)
# Out:
# Cluster 0:-------------------------------
# drugs
# said
# court
# police
# possession
# drug
# county
# degree
# cocaine
# guilty
# Cluster 1:-------------------------------
# indicted
# count
# possession
# aggravated
# direct
# hamilton
# ave
# middletown
# st
# counts
# Cluster 2:-------------------------------
# drugs
# drug
# said
# iran
# international
# police
# paraguay
# hezbollah
# narcotics
# countries
# Cluster 3:-------------------------------
# australian
# australia
# yacht
# police
# arunga
# islands
# said
# parole
# cook
# island
# Cluster 4:-------------------------------
# duterte
# war
# drug
# president
# robredo
# said
# drugs
# illegal
# police
# philippines
# Cluster 5:-------------------------------
# market
# drugs
# global
# research
# growth
# mondaq
# report
# forecast
# analysis
# com
# Cluster 6:-------------------------------
# 99per
# 24weeks
# opioid
# fentanyl
# globeandmail
# week
# just
# crisis
# opioids
# said
# ...
